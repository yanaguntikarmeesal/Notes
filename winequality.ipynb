# %% [markdown]
# <a href="https://colab.research.google.com/github/yanaguntikarmeesal/Notes/blob/main/winequality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LEARNING THE EDA**

# %%
import pandas as pd
df = pd.read_csv('winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70            0             1.9     0.0760
# 1            0.1              0.06            1             2.6     0.0023
# 2            0.2              0.07            2             2.6     0.0024
# 3            0.3              0.08            4             2.6     0.0025
# 4            0.4              0.09            0             2.6     0.0026
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   11                    34   0.9978  3.51      0.560
# 1                   25                    67   0.9680  0.01      0.001
# 2                   25                    65   0.9781  0.02      0.002
# 3                   26                    63   0.9882  0.03      0.003
# 4                   24                    10   0.9983  0.04      0.004
#
#    alcohol  quality
# 0    9.400        5
# 1    0.002        5
# 2    0.003        6
# ...

# %% [markdown]
# # summary of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1681 entries, 0 to 1680
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1681 non-null   float64
#  1   volatile acidity      1681 non-null   float64
#  2   citric acid           1681 non-null   int64
#  3   residual sugar        1681 non-null   float64
#  4   chlorides             1681 non-null   float64
#  5   free sulfur dioxide   1681 non-null   int64
#  6   total sulfur dioxide  1681 non-null   int64
#  7   density               1681 non-null   float64
#  8   pH                    1681 non-null   float64
#  9   sulphates             1681 non-null   float64
#  10  alcohol               1681 non-null   float64
#  11  quality               1681 non-null   int64
# dtypes: float64(8), int64(4)
# memory usage: 157.7 KB

# %% [markdown]
# # descriptive summary of the dataset

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1681.000000       1681.000000  1681.000000     1681.000000
# mean       82.016895          6.364658     1.844735        4.872606
# std        48.512313          4.458379     1.460283        3.076625
# min         0.000000          0.000000     0.000000        0.000000
# 25%        40.000000          1.880000     1.000000        2.600000
# 50%        82.000000          6.080000     2.000000        4.200000
# 75%       124.000000         10.280000     4.000000        7.200000
# max       166.000000         14.480000     4.000000       14.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1681.000000          1681.000000           1681.000000  1681.000000
# mean      0.078441           191.381321            208.829268     8.625896
# std       0.040379           157.374017            179.753300     4.866498
# ...

# %% [markdown]
# # shape of the dataset

# %%
df.shape
# Out:
# (1681, 12)

# %% [markdown]
# # List down the column names

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# # unique value in quality columns

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 8, 4, 3, 0])

# %%
df['quality'].value_counts()
# Out:
# quality
# 5    382
# 3    317
# 7    315
# 8    240
# 4    227
# 6    180
# 0     20
# Name: count, dtype: int64

# %% [markdown]
# # Missing values in dataset

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# # check duplication value in dataset

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1676     True
# 1677     True
# 1678     True
# 1679     True
# 1680     True
# Length: 1681, dtype: bool

# %%
df[df.duplicated()]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1663            0.0              0.88            0             2.6      0.098
# 1664            0.0              0.88            0             2.6      0.098
# 1665            0.0              0.88            0             2.6      0.098
# 1666            0.0              0.88            0             2.6      0.098
# 1667            0.0              0.88            0             2.6      0.098
# 1668            0.0              0.88            0             2.6      0.098
# 1669            0.0              0.88            0             2.6      0.098
# 1670            0.0              0.88            0             2.6      0.098
# 1671            0.0              0.88            0             2.6      0.098
# 1672            0.0              0.88            0             2.6      0.098
# 1673            0.0              0.88            0             2.6      0.098
# ...

# %% [markdown]
# # remove the duplicate record

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1658    False
# 1659    False
# 1660    False
# 1661    False
# 1662    False
# Length: 1663, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (1663, 12)

# %% [markdown]
# # correlate

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.427829     0.005360
# volatile acidity           0.427829          1.000000     0.003462
# citric acid                0.005360          0.003462     1.000000
# residual sugar            -0.071243          0.244357     0.004674
# chlorides                  0.914720          0.718187     0.002400
# free sulfur dioxide       -0.283550          0.155058     0.000397
# total sulfur dioxide       0.190899          0.549521     0.001570
# density                    0.790119          0.590810     0.003422
# pH                         0.616226         -0.307902    -0.002193
# sulphates                  0.999089          0.426630     0.003493
# alcohol                    0.619635          0.156729    -0.001545
# quality                    0.011341          0.012210     0.001727
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# # visually of correlation of dataset

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(),annot=True)
plt.colorbar
plt.show()

# %%
df.quality.value_counts()
# Out:
# quality
# 5    382
# 3    317
# 7    315
# 8    240
# 4    227
# 6    180
# 0      2
# Name: count, dtype: int64

# %%
df.quality.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='quality'>

# %%
df.head(2)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70            0             1.9     0.0760
# 1            0.1              0.06            1             2.6     0.0023
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   11                    34   0.9978  3.51      0.560
# 1                   25                    67   0.9680  0.01      0.001
#
#    alcohol  quality
# 0    9.400        5
# 1    0.002        5

# %%
sns.displot(df['fixed acidity'],kde=True)

# %%
for i in df.columns:
    sns.displot(df[i],kde=True)
    plt.show()

# %%
df.head(2)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70            0             1.9     0.0760
# 1            0.1              0.06            1             2.6     0.0023
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   11                    34   0.9978  3.51      0.560
# 1                   25                    67   0.9680  0.01      0.001
#
#    alcohol  quality
# 0    9.400        5
# 1    0.002        5

# %%
# categorical plot
sns.catplot(x='quality',data=df,kind='count')

# %%
# categorical plot
sns.catplot(x='quality',y='alcohol',data=df,kind='box')

# %%
sns.scatterplot(x='alcohol', y='pH', hue='quality', data=df)
# Out:
# <Axes: xlabel='alcohol', ylabel='pH'>
